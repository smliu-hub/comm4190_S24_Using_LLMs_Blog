# %% [raw]
# ---
# title: "A test post"
# description: "An example post from a Jupyter notebook"
# author: "An LLM User"
# date: "2/2/2024"
# categories:
#   - LLMs
#   - prompting
#   - logic
# ---

# %% [markdown]
# ## This is a blog post
#
# ![小黑！.jpg](attachment:6f009a59-07ce-45ac-86cb-f3e478bb598c.jpg)

# %%
for id
